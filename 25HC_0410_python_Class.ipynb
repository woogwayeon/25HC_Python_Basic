# %% [markdown]
# <a href="https://colab.research.google.com/github/woogwayeon/25HC_Python_Basic/blob/master/25HC_0410_python_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 클래스 - Class
#
#
#     💚 python에서 문자형 자료 선언하면 그 변수에 기능까지 상속된다고 생각하면 된다!
#
#     💚 이런 것을 하나로 묶어서 class라고 생각하면 된다!
#
#     💚 파이선에서는 모든 자료형이 클래스로 이뤄져있다
#     이 안에 있는 기능을 쓰려면 함수 안에 있는 메서드를 이용해야 한다! (사실상 함수랑 같음)

# %% [markdown]
# ## self
#
# ![image.png](data:image/png;base64,...)
#
#     def setdata(self, first, second)
#     메서드를 사용할 때는 self를 사용해줘야 한다
#
#
# ![image.png](data:image/png;base64,...)
#
#
#     self가 있으면 클래스의 소속이라는 뜻이다

# %% [markdown]
# ## constructor (생성자)
#
# ![image.png](data:image/png;base64,...)
#
#
#     self의 개념을 this라고 생각해보자

# %% [markdown]
# ## Inheritence - 상속
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## MRO - 클래스의 상속순서
#
#     메서드 레졸루션 오더라고 해서 상속관계 알아보기
#
# ![image.png](data:image/png;base64,...)
#
#     우선순위는 왼쪽부터 이루어진다
#     python에서 다중상속 하고 super()를 사용하면 왼쪽부터 상속 순서 어쩌고가 달라짐
#
# ![image.png](data:image/png;base64,...)
#
#     python에서는 다중상속도 가능하다(?)
#     모든 클래스에는 상속정보가 저장되어 있어서.. 탐색순서를 알아볼 수 있다

# %% [markdown]
# ## 다중상속
#
# ![image.png](data:image/png;base64,...)
#
#     두개 상속받은 친구는 두개 다 들어가서 사용할 수 있다
#     이 다중상속을 이해하기 위해 MRO를 이해해야 한다
#     순서를 알아두자
