# %% [markdown]
# <a href="https://colab.research.google.com/github/woogwayeon/25HC_Python_Basic/blob/master/25HC_0410_python_Module_Package.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 모듈과 패키지
#
# ![image.png](data:image/png;base64,...)
#
#     package : 하나의 폴더
#     module : 하나의 파일이라고 생각
#
#     즉 패키지가 더 큰 상위개념이다

# %% [markdown]
# # import 혼자서 함수를 가져올 수 없다
