# %% [markdown]
# <a href="https://colab.research.google.com/github/woogwayeon/25HC_Python_Basic/blob/master/25HC_0508_python_charset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # python과 unicode
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ASCII code?
#
# 미국에서 만든 문자셋!
# 근데 이제 전세계에서는 안통하는..

# %% [markdown]
# ## unicode
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 인코딩과 디코딩의 역사는 새로운 기술의 변화와 연결되어 있따
# windows에서 cp949를 처음에 만들었다!
#
# euc-kr이랑 같다
#
# 매모장에서 다른이름으로 저장 하면
#
#     ANSI (아주 옛날 옛적 저장 방식)
#
#     UTF-8 LE - little endian?
#
#     UTF-8 BE - big endian?
#
#     UTF-8 BOM

# %%
# 실습하기

a = "life is too long"
b = a.encode("utf-8") # 인코딩되어서 타입이 바이트로 나온다

print(b)
print(f"a = {type(a)} , b = {type(b)}")
# Out:
# b'life is too long'
# a = <class 'str'> , b = <class 'bytes'>

# %% [markdown]
# ## euc - kr 읽어보기

# %%
# 파일 만들기
with open('euc-kr.txt', encoding='euc-kr', mode = 'w') as f :
    f.write("hellooooo") # 한글은 안돼요!

with open('euc-kr.txt', encoding='utf-8', mode='r') as f :  # 영문은 문제없지만
    data = f.read()
    print(data)
# Out:
# hellooooo

# %% [markdown]
# ### 인코딩 타입 명시

# %%
#-*- coding :  utf-8 -*-
